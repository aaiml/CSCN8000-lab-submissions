# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score

# %% [markdown]
# - Data Analysis

# %%
pSData = pd.read_csv("pd_speech_features.csv", header=1)
pSData.head(10)
# Out:
#    id  gender      PPE      DFA     RPDE  numPulses  numPeriodsPulses
# 0   0       1  0.85247  0.71826  0.57227        240               239  \
# 1   0       1  0.76686  0.69481  0.53966        234               233
# 2   0       1  0.85083  0.67604  0.58982        232               231
# 3   1       0  0.41121  0.79672  0.59257        178               177
# 4   1       0  0.32790  0.79782  0.53028        236               235
# 5   1       0  0.50780  0.78744  0.65451        226               221
# 6   2       1  0.76095  0.62145  0.54543        322               321
# 7   2       1  0.83671  0.62079  0.51179        318               317
# 8   2       1  0.80826  0.61766  0.50447        318               317
# 9   3       0  0.85302  0.62247  0.54855        493               492
#
#    meanPeriodPulses  stdDevPeriodPulses  locPctJitter  ...
# 0          0.008064            0.000087       0.00218  ...  \
# 1          0.008258            0.000073       0.00195  ...
# ...

# %% [markdown]
# - Data Preprocessing

# %%
# Check for any missing values
print(pSData.isnull().sum())
# Out:
# id                           0
# gender                       0
# PPE                          0
# DFA                          0
# RPDE                         0
#                             ..
# tqwt_kurtosisValue_dec_33    0
# tqwt_kurtosisValue_dec_34    0
# tqwt_kurtosisValue_dec_35    0
# tqwt_kurtosisValue_dec_36    0
# class                        0
# Length: 755, dtype: int64

# %%
pSData.drop_duplicates(inplace=True)  # Remove duplicates
pSData.dropna()  # Removing NaN values
pSData.head(10)
# Out:
#    id  gender      PPE      DFA     RPDE  numPulses  numPeriodsPulses
# 0   0       1  0.85247  0.71826  0.57227        240               239  \
# 1   0       1  0.76686  0.69481  0.53966        234               233
# 2   0       1  0.85083  0.67604  0.58982        232               231
# 3   1       0  0.41121  0.79672  0.59257        178               177
# 4   1       0  0.32790  0.79782  0.53028        236               235
# 5   1       0  0.50780  0.78744  0.65451        226               221
# 6   2       1  0.76095  0.62145  0.54543        322               321
# 7   2       1  0.83671  0.62079  0.51179        318               317
# 8   2       1  0.80826  0.61766  0.50447        318               317
# 9   3       0  0.85302  0.62247  0.54855        493               492
#
#    meanPeriodPulses  stdDevPeriodPulses  locPctJitter  ...
# 0          0.008064            0.000087       0.00218  ...  \
# 1          0.008258            0.000073       0.00195  ...
# ...

# %% [markdown]
# - Data Standardization

# %%
X = pSData.drop(columns=['class'])
y = pSData['class']

# %%
# Standardize numerical features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %% [markdown]
# - Model Training

# %% [markdown]
# -  a. Use 80% of samples as training data size.

# %%
# Split the data into training (80%) and testing (20%) sets
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)
model = LogisticRegression()
model.fit(X_train, y_train)
# Out:
# d:\College Stuff\CSCN8010\venv\CSCN8010_classic_ml\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %% [markdown]
# - Measure your model’s accuracy.

# %%
y_pred = model.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print(f"Model Accuracy: {accuracy:.2f}")
# Out:
# Model Accuracy: 0.83

# %% [markdown]
# - Build a predictive system to verify that the model built is able to predict the patient’s Parkinson’s disease with one instance of the dataset.

# %%
# Assuming 'new_instance' is a single instance from the dataset for prediction
new_instance = X.iloc[0, :].values  # Selecting the first instance from the dataset for prediction

# Preprocess the new instance using the same scaler used for training data
new_instance_scaled = scaler.transform([new_instance])

# Use the trained model to predict whether the patient is likely to have Parkinson's disease
prediction = model.predict(new_instance_scaled)

# 'prediction' will contain the predicted label (0: No Parkinson's, 1: Parkinson's)
print("Predicted label:", prediction[0])
# Out:
# Predicted label: 1
# d:\College Stuff\CSCN8010\venv\CSCN8010_classic_ml\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
